# %% [markdown]
# Every GA program follows this template:
# 1. Initialize population
# 2. Evaluate fitness
# 3. Selection
# 4. Crossover
# 5. Mutation
# 6. Repeat for generations

# %% [markdown]
# # Task 1: Binary String Maximization

# %%
import random

POP_SIZE = 6
CHROMOSOME_LENGTH = 10
GENERATIONS = 10
MUTATION_RATE = 0.1


# --------------------------
# 1. Initialize Population
# --------------------------
def initialize_population():

    population = []

    # TODO: generate POP_SIZE chromosomes
    # each chromosome = binary list of length CHROMOSOME_LENGTH

    return population


# --------------------------
# 2. Fitness Function
# --------------------------
def fitness(chromosome):

    # TODO:
    # fitness = number of 1s in chromosome

    pass


# --------------------------
# 3. Selection
# --------------------------
def selection(population, fitnesses):

    # TODO:
    # implement roulette wheel selection
    # return two parents

    pass


# --------------------------
# 4. Crossover
# --------------------------
def crossover(parent1, parent2):

    # TODO:
    # implement single point crossover

    pass


# --------------------------
# 5. Mutation
# --------------------------
def mutate(chromosome):

    # TODO:
    # flip bit with probability MUTATION_RATE

    pass


# --------------------------
# GA Main Loop
# --------------------------
def genetic_algorithm():

    pass

genetic_algorithm()

# %% [markdown]
# # Task 2: Function Maximization

# %%
import random
import math

POP_SIZE = 6
GENERATIONS = 10
MUTATION_RATE = 0.1
LOWER_BOUND = 0
UPPER_BOUND = 1


# --------------------------
# 1. Initialize Population
# --------------------------
def initialize_population():

    # TODO:
    # generate random real numbers between LOWER_BOUND and UPPER_BOUND

    pass


# --------------------------
# 2. Fitness Function
# --------------------------
def fitness(x):

    # TODO:
    # compute f(x) = x*sin(10πx) + 1

    pass


# --------------------------
# 3. Selection
# --------------------------
def selection(population):

    # TODO:
    # implement tournament selection

    pass


# --------------------------
# 4. Crossover
# --------------------------
def crossover(p1, p2):

    # TODO:
    # implement arithmetic crossover

    pass


# --------------------------
# 5. Mutation
# --------------------------
def mutate(x):

    # TODO:
    # add small random value to x

    pass

# --------------------------
# GA Main Loop
# --------------------------
def genetic_algorithm():

    pass

genetic_algorithm()

# %% [markdown]
# # Task 3: 0/1 Knapsack

# %%
import random

weights = [2,3,4,5]
values = [3,4,5,8]

MAX_WEIGHT = 8

POP_SIZE = 6
CHROMOSOME_LENGTH = 4
GENERATIONS = 10
MUTATION_RATE = 0.1


# --------------------------
# 1. Initialize Population
# --------------------------
def initialize_population():

    # TODO:
    # binary chromosomes of length 4

    pass


# --------------------------
# 2. Fitness Function
# --------------------------
def fitness(chromosome):

    # TODO:
    # compute total weight
    # compute total value
    # if weight > MAX_WEIGHT return 0

    pass


# --------------------------
# 3. Selection
# --------------------------
def selection(population, fitnesses):

    # TODO:
    # roulette wheel selection

    pass


# --------------------------
# 4. Crossover
# --------------------------
def crossover(p1, p2):

    # TODO:
    # single point crossover

    pass


# --------------------------
# 5. Mutation
# --------------------------
def mutate(chromosome):

    # TODO:
    # bit flip mutation

    pass

# --------------------------
# GA Main Loop
# --------------------------
def genetic_algorithm():

    pass

genetic_algorithm()

# %% [markdown]
# # Task 4: Traveling Salesman Problem (TSP)

# %%
import random

cities = ['A','B','C','D','E']

POP_SIZE = 6
GENERATIONS = 10


# --------------------------
# 1. Initialize Population
# --------------------------
def initialize_population():

    # TODO:
    # create random permutations of cities

    pass


# --------------------------
# 2. Fitness Function
# --------------------------
def fitness(route):

    # TODO:
    # compute total route distance
    # fitness = 1 / total_distance

    pass


# --------------------------
# 3. Selection
# --------------------------
def selection(population):

    # TODO:
    # tournament selection

    pass


# --------------------------
# 4. Crossover
# --------------------------
def crossover(p1, p2):

    # TODO:
    # order crossover (OX)

    pass


# --------------------------
# 5. Mutation
# --------------------------
def mutate(route):

    # TODO:
    # swap two cities

    pass

# --------------------------
# GA Main Loop
# --------------------------
def genetic_algorithm():

    pass

genetic_algorithm()

# %% [markdown]
# # Task 5: Evolving Logical Expressions (Symbolic GA)

# %%
import random

POP_SIZE = 6
GENERATIONS = 10
MUTATION_RATE = 0.1


# --------------------------
# 1. Initialize Population
# --------------------------
def initialize_population():

    # TODO:
    # binary chromosomes of length 3

    pass


# --------------------------
# 2. Fitness Function
# --------------------------
def fitness(chromosome):

    # TODO:
    # evaluate logical expression
    # compare with truth table
    # return number of matches

    pass


# --------------------------
# 3. Selection
# --------------------------
def selection(population, fitnesses):

    # TODO:
    # roulette selection

    pass


# --------------------------
# 4. Crossover
# --------------------------
def crossover(p1, p2):

    # TODO:
    # single point crossover

    pass


# --------------------------
# 5. Mutation
# --------------------------
def mutate(chromosome):

    # TODO:
    # flip bit

    pass

# --------------------------
# GA Main Loop
# --------------------------
def genetic_algorithm():

    pass

genetic_algorithm()

# %% [markdown]
# # Task 6: GA for Simple Equation Solving

# %%
import random

POP_SIZE = 6
GENERATIONS = 10


# --------------------------
# 1. Initialize Population
# --------------------------
def initialize_population():

    # TODO:
    # generate [x,y] pairs

    pass


# --------------------------
# 2. Fitness Function
# --------------------------
def fitness(chromosome):

    # TODO:
    # compute error = |x^2 + y^2 - 50|
    # fitness = 1 / (1 + error)

    pass


# --------------------------
# 3. Selection
# --------------------------
def selection(population):

    # TODO:
    # tournament selection

    pass


# --------------------------
# 4. Crossover
# --------------------------
def crossover(p1, p2):

    # TODO:
    # average crossover

    pass


# --------------------------
# 5. Mutation
# --------------------------
def mutate(chromosome):

    # TODO:
    # modify x or y by ±1

    pass

# --------------------------
# GA Main Loop
# --------------------------
def genetic_algorithm():

    pass

genetic_algorithm()
